# %%
# %load_ext autoreload
# %autoreload 2
# %env ANYWIDGET_HMR=1
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# env: ANYWIDGET_HMR=1

# %%
import sys, os
sys.path.append(os.path.abspath("src"))

# %%
from gnn_vis_widgets import Widget
Widget()
# Out:
# Widget()
