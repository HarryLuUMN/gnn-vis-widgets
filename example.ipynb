# %%
# %load_ext autoreload
# %autoreload 2
# %env ANYWIDGET_HMR=1
# Out:
# env: ANYWIDGET_HMR=1

# %%
import sys, os
sys.path.append(os.path.abspath("src"))

# %% [markdown]
# ## Visualizing Graphs with Dual Views

# %%
from gnn_vis_widgets import GraphVisualizer
GraphVisualizer(dataFile="/files/test_data/karate_dataset.json")
# Out:
# GraphVisualizer()

# %%
GraphVisualizer(dataFile="/files/test_data/input_graph0.json")
# Out:
# GraphVisualizer(dataFile='/files/test_data/input_graph0.json')
